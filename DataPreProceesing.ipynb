# %% [markdown]
# # Data PreProcessing

# %%
import pandas as pd

data = pd.read_csv('placement 1.csv')
data
# Out:
#      Unnamed: 0 gender  degree_p   degree_t workex  etest_p specialisation  \
# 0             0      M     58.00   Sci&Tech     No     55.0         Mkt&HR
# 1             1      M     77.48   Sci&Tech    Yes     86.5        Mkt&Fin
# 2             2      M     64.00  Comm&Mgmt     No     75.0        Mkt&Fin
# 3             3      M     52.00   Sci&Tech    NaN     66.0         Mkt&HR
# 4             4      M     73.30  Comm&Mgmt     No     96.8        Mkt&Fin
# ..          ...    ...       ...        ...    ...      ...            ...
# 210         210      M     77.60  Comm&Mgmt     No     91.0        Mkt&Fin
# 211         211      M     72.00   Sci&Tech     No     74.0        Mkt&Fin
# 212         212      M     73.00  Comm&Mgmt    Yes     59.0        Mkt&Fin
# 213         213      F     58.00  Comm&Mgmt     No      NaN         Mkt&HR
# 214         214      M     53.00  Comm&Mgmt     No     89.0         Mkt&HR
#
#      mba_p       salary
# 0    58.80  270000.0000
# ...

# %%
data.isnull().sum().sum()
# Out:
# 44

# %%
data.dropna(how = 'any')
# Out:
#      Unnamed: 0 gender  degree_p   degree_t workex  etest_p specialisation  \
# 0             0      M     58.00   Sci&Tech     No     55.0         Mkt&HR
# 1             1      M     77.48   Sci&Tech    Yes     86.5        Mkt&Fin
# 2             2      M     64.00  Comm&Mgmt     No     75.0        Mkt&Fin
# 4             4      M     73.30  Comm&Mgmt     No     96.8        Mkt&Fin
# 5             5      M     67.25   Sci&Tech    Yes     55.0        Mkt&Fin
# ..          ...    ...       ...        ...    ...      ...            ...
# 209         209      M     65.00  Comm&Mgmt     No     67.0        Mkt&Fin
# 210         210      M     77.60  Comm&Mgmt     No     91.0        Mkt&Fin
# 211         211      M     72.00   Sci&Tech     No     74.0        Mkt&Fin
# 212         212      M     73.00  Comm&Mgmt    Yes     59.0        Mkt&Fin
# 214         214      M     53.00  Comm&Mgmt     No     89.0         Mkt&HR
#
#      mba_p       salary
# 0    58.80  270000.0000
# ...

# %%
data.shape
# Out:
# (215, 9)

# %%
data.describe()
# Out:
#        Unnamed: 0    degree_p     etest_p       mba_p         salary
# count  215.000000  207.000000  206.000000  200.000000     211.000000
# mean   107.000000   66.148019   71.934272   62.288950  288795.792236
# std     62.209324    7.302777   13.268486    5.936314   77867.382898
# min      0.000000   50.000000   50.000000   51.210000  200000.000000
# 25%     53.500000   61.000000   60.000000   57.875000  250000.000000
# 50%    107.000000   65.600000   70.500000   61.885000  288655.405400
# 75%    160.500000   71.825000   82.915000   66.325000  288655.405400
# max    214.000000   91.000000   98.000000   77.890000  940000.000000

# %%
data.dtype()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-2d09d10b65c9> in <module>
# ----> 1 data.dtype()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
result = data.dtypes
print(result)
# Out:
# Unnamed: 0          int64
# gender             object
# degree_p          float64
# degree_t           object
# workex             object
# etest_p           float64
# specialisation     object
# mba_p             float64
# salary            float64
# dtype: object

# %%
data.drop_duplicates()
# Out:
#      Unnamed: 0 gender  degree_p   degree_t workex  etest_p specialisation  \
# 0             0      M     58.00   Sci&Tech     No     55.0         Mkt&HR
# 1             1      M     77.48   Sci&Tech    Yes     86.5        Mkt&Fin
# 2             2      M     64.00  Comm&Mgmt     No     75.0        Mkt&Fin
# 3             3      M     52.00   Sci&Tech    NaN     66.0         Mkt&HR
# 4             4      M     73.30  Comm&Mgmt     No     96.8        Mkt&Fin
# ..          ...    ...       ...        ...    ...      ...            ...
# 210         210      M     77.60  Comm&Mgmt     No     91.0        Mkt&Fin
# 211         211      M     72.00   Sci&Tech     No     74.0        Mkt&Fin
# 212         212      M     73.00  Comm&Mgmt    Yes     59.0        Mkt&Fin
# 213         213      F     58.00  Comm&Mgmt     No      NaN         Mkt&HR
# 214         214      M     53.00  Comm&Mgmt     No     89.0         Mkt&HR
#
#      mba_p       salary
# 0    58.80  270000.0000
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0         0
# gender             0
# degree_p           8
# degree_t           0
# workex             4
# etest_p            9
# specialisation     4
# mba_p             15
# salary             4
# dtype: int64

# %%
data.dropna(how='all')
# Out:
#      Unnamed: 0 gender  degree_p   degree_t workex  etest_p specialisation  \
# 0             0      M     58.00   Sci&Tech     No     55.0         Mkt&HR
# 1             1      M     77.48   Sci&Tech    Yes     86.5        Mkt&Fin
# 2             2      M     64.00  Comm&Mgmt     No     75.0        Mkt&Fin
# 3             3      M     52.00   Sci&Tech    NaN     66.0         Mkt&HR
# 4             4      M     73.30  Comm&Mgmt     No     96.8        Mkt&Fin
# ..          ...    ...       ...        ...    ...      ...            ...
# 210         210      M     77.60  Comm&Mgmt     No     91.0        Mkt&Fin
# 211         211      M     72.00   Sci&Tech     No     74.0        Mkt&Fin
# 212         212      M     73.00  Comm&Mgmt    Yes     59.0        Mkt&Fin
# 213         213      F     58.00  Comm&Mgmt     No      NaN         Mkt&HR
# 214         214      M     53.00  Comm&Mgmt     No     89.0         Mkt&HR
#
#      mba_p       salary
# 0    58.80  270000.0000
# ...

# %%
data.dropna(how = 'any',inplace = True)

# %%
data
# Out:
#      Unnamed: 0 gender  degree_p   degree_t workex  etest_p specialisation  \
# 0             0      M     58.00   Sci&Tech     No     55.0         Mkt&HR
# 1             1      M     77.48   Sci&Tech    Yes     86.5        Mkt&Fin
# 2             2      M     64.00  Comm&Mgmt     No     75.0        Mkt&Fin
# 4             4      M     73.30  Comm&Mgmt     No     96.8        Mkt&Fin
# 5             5      M     67.25   Sci&Tech    Yes     55.0        Mkt&Fin
# ..          ...    ...       ...        ...    ...      ...            ...
# 209         209      M     65.00  Comm&Mgmt     No     67.0        Mkt&Fin
# 210         210      M     77.60  Comm&Mgmt     No     91.0        Mkt&Fin
# 211         211      M     72.00   Sci&Tech     No     74.0        Mkt&Fin
# 212         212      M     73.00  Comm&Mgmt    Yes     59.0        Mkt&Fin
# 214         214      M     53.00  Comm&Mgmt     No     89.0         Mkt&HR
#
#      mba_p       salary
# 0    58.80  270000.0000
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0        0
# gender            0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# salary            0
# dtype: int64

# %%
import pandas as pd

data = pd.read_csv('placement 1.csv')
data
# Out:
#      Unnamed: 0 gender  degree_p   degree_t workex  etest_p specialisation  \
# 0             0      M     58.00   Sci&Tech     No     55.0         Mkt&HR
# 1             1      M     77.48   Sci&Tech    Yes     86.5        Mkt&Fin
# 2             2      M     64.00  Comm&Mgmt     No     75.0        Mkt&Fin
# 3             3      M     52.00   Sci&Tech    NaN     66.0         Mkt&HR
# 4             4      M     73.30  Comm&Mgmt     No     96.8        Mkt&Fin
# ..          ...    ...       ...        ...    ...      ...            ...
# 210         210      M     77.60  Comm&Mgmt     No     91.0        Mkt&Fin
# 211         211      M     72.00   Sci&Tech     No     74.0        Mkt&Fin
# 212         212      M     73.00  Comm&Mgmt    Yes     59.0        Mkt&Fin
# 213         213      F     58.00  Comm&Mgmt     No      NaN         Mkt&HR
# 214         214      M     53.00  Comm&Mgmt     No     89.0         Mkt&HR
#
#      mba_p       salary
# 0    58.80  270000.0000
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0         0
# gender             0
# degree_p           8
# degree_t           0
# workex             4
# etest_p            9
# specialisation     4
# mba_p             15
# salary             4
# dtype: int64

# %%
data['salary'].isnull().sum()
# Out:
# 4

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'gender', 'degree_p', 'degree_t', 'workex', 'etest_p',
#        'specialisation', 'mba_p', 'salary'],
#       dtype='object')

# %%
data.columns[0]
# Out:
# 'Unnamed: 0'

# %%
colLength = len(data.columns)

for i in range(colLength):
    colName = data.columns[i]
    nullColSum = data[colName].isnull().sum()
    print(f'{colName} : {nullColSum}')
# Out:
# Unnamed: 0 : 0
# gender : 0
# degree_p : 8
# degree_t : 0
# workex : 4
# etest_p : 9
# specialisation : 4
# mba_p : 15
# salary : 4

# %%
data.drop_duplicates()
# Out:
#      Unnamed: 0 gender  degree_p   degree_t workex  etest_p specialisation  \
# 0             0      M     58.00   Sci&Tech     No     55.0         Mkt&HR
# 1             1      M     77.48   Sci&Tech    Yes     86.5        Mkt&Fin
# 2             2      M     64.00  Comm&Mgmt     No     75.0        Mkt&Fin
# 3             3      M     52.00   Sci&Tech    NaN     66.0         Mkt&HR
# 4             4      M     73.30  Comm&Mgmt     No     96.8        Mkt&Fin
# ..          ...    ...       ...        ...    ...      ...            ...
# 210         210      M     77.60  Comm&Mgmt     No     91.0        Mkt&Fin
# 211         211      M     72.00   Sci&Tech     No     74.0        Mkt&Fin
# 212         212      M     73.00  Comm&Mgmt    Yes     59.0        Mkt&Fin
# 213         213      F     58.00  Comm&Mgmt     No      NaN         Mkt&HR
# 214         214      M     53.00  Comm&Mgmt     No     89.0         Mkt&HR
#
#      mba_p       salary
# 0    58.80  270000.0000
# ...

# %%
mean = data['etest_p'].mean()
print(mean)
# Out:
# 71.93427184466019

# %%
data['etest_p'].fillna(mean,inplace=True)

# %%
data
# Out:
#      Unnamed: 0 gender  degree_p   degree_t workex    etest_p specialisation  \
# 0             0      M     58.00   Sci&Tech     No  55.000000         Mkt&HR
# 1             1      M     77.48   Sci&Tech    Yes  86.500000        Mkt&Fin
# 2             2      M     64.00  Comm&Mgmt     No  75.000000        Mkt&Fin
# 3             3      M     52.00   Sci&Tech    NaN  66.000000         Mkt&HR
# 4             4      M     73.30  Comm&Mgmt     No  96.800000        Mkt&Fin
# ..          ...    ...       ...        ...    ...        ...            ...
# 210         210      M     77.60  Comm&Mgmt     No  91.000000        Mkt&Fin
# 211         211      M     72.00   Sci&Tech     No  74.000000        Mkt&Fin
# 212         212      M     73.00  Comm&Mgmt    Yes  59.000000        Mkt&Fin
# 213         213      F     58.00  Comm&Mgmt     No  71.934272         Mkt&HR
# 214         214      M     53.00  Comm&Mgmt     No  89.000000         Mkt&HR
#
#      mba_p       salary
# ...

# %%
data['etest_p'].isnull().sum()
# Out:
# 0

# %%
data['salary'].isnull().sum()
# Out:
# 4

# %%
data.dropna(subset=['salary'],inplace = True)

# %%
data
# Out:
#      Unnamed: 0 gender  degree_p   degree_t workex    etest_p specialisation  \
# 0             0      M     58.00   Sci&Tech     No  55.000000         Mkt&HR
# 1             1      M     77.48   Sci&Tech    Yes  86.500000        Mkt&Fin
# 2             2      M     64.00  Comm&Mgmt     No  75.000000        Mkt&Fin
# 3             3      M     52.00   Sci&Tech    NaN  66.000000         Mkt&HR
# 4             4      M     73.30  Comm&Mgmt     No  96.800000        Mkt&Fin
# ..          ...    ...       ...        ...    ...        ...            ...
# 210         210      M     77.60  Comm&Mgmt     No  91.000000        Mkt&Fin
# 211         211      M     72.00   Sci&Tech     No  74.000000        Mkt&Fin
# 212         212      M     73.00  Comm&Mgmt    Yes  59.000000        Mkt&Fin
# 213         213      F     58.00  Comm&Mgmt     No  71.934272         Mkt&HR
# 214         214      M     53.00  Comm&Mgmt     No  89.000000         Mkt&HR
#
#      mba_p       salary
# ...

# %%
data['salary'].isnull().sum()
# Out:
# 0

# %%
data['degree_p'].isnull().sum()
# Out:
# 8

# %%
mean = data['degree_p'].mean()
print(mean)
# Out:
# 66.09059113300493

# %%
data['degree_p'].fillna(mean,inplace = True)

# %%
data
# Out:
#      Unnamed: 0 gender  degree_p   degree_t workex    etest_p specialisation  \
# 0             0      M     58.00   Sci&Tech     No  55.000000         Mkt&HR
# 1             1      M     77.48   Sci&Tech    Yes  86.500000        Mkt&Fin
# 2             2      M     64.00  Comm&Mgmt     No  75.000000        Mkt&Fin
# 3             3      M     52.00   Sci&Tech    NaN  66.000000         Mkt&HR
# 4             4      M     73.30  Comm&Mgmt     No  96.800000        Mkt&Fin
# ..          ...    ...       ...        ...    ...        ...            ...
# 210         210      M     77.60  Comm&Mgmt     No  91.000000        Mkt&Fin
# 211         211      M     72.00   Sci&Tech     No  74.000000        Mkt&Fin
# 212         212      M     73.00  Comm&Mgmt    Yes  59.000000        Mkt&Fin
# 213         213      F     58.00  Comm&Mgmt     No  71.934272         Mkt&HR
# 214         214      M     53.00  Comm&Mgmt     No  89.000000         Mkt&HR
#
#      mba_p       salary
# ...

# %%
data['degree_p'].isnull().sum()
# Out:
# 0

# %%
data['degree_t'].isnull().sum()
# Out:
# 0

# %%
data.dropna(how = 'all',inplace = True)

# %%
data
# Out:
#      Unnamed: 0 gender  degree_p   degree_t workex    etest_p specialisation  \
# 0             0      M     58.00   Sci&Tech     No  55.000000         Mkt&HR
# 1             1      M     77.48   Sci&Tech    Yes  86.500000        Mkt&Fin
# 2             2      M     64.00  Comm&Mgmt     No  75.000000        Mkt&Fin
# 3             3      M     52.00   Sci&Tech    NaN  66.000000         Mkt&HR
# 4             4      M     73.30  Comm&Mgmt     No  96.800000        Mkt&Fin
# ..          ...    ...       ...        ...    ...        ...            ...
# 210         210      M     77.60  Comm&Mgmt     No  91.000000        Mkt&Fin
# 211         211      M     72.00   Sci&Tech     No  74.000000        Mkt&Fin
# 212         212      M     73.00  Comm&Mgmt    Yes  59.000000        Mkt&Fin
# 213         213      F     58.00  Comm&Mgmt     No  71.934272         Mkt&HR
# 214         214      M     53.00  Comm&Mgmt     No  89.000000         Mkt&HR
#
#      mba_p       salary
# ...

# %%
data['workex'].isnull().sum()
# Out:
# 4

# %%
data['workex'].value_counts()
# Out:
# No     137
# Yes     70
# Name: workex, dtype: int64

# %%
data['workex'].fillna(data['workex'].value_counts().index[0],inplace = True)

# %%
data
# Out:
#      Unnamed: 0 gender  degree_p   degree_t workex    etest_p specialisation  \
# 0             0      M     58.00   Sci&Tech     No  55.000000         Mkt&HR
# 1             1      M     77.48   Sci&Tech    Yes  86.500000        Mkt&Fin
# 2             2      M     64.00  Comm&Mgmt     No  75.000000        Mkt&Fin
# 3             3      M     52.00   Sci&Tech     No  66.000000         Mkt&HR
# 4             4      M     73.30  Comm&Mgmt     No  96.800000        Mkt&Fin
# ..          ...    ...       ...        ...    ...        ...            ...
# 210         210      M     77.60  Comm&Mgmt     No  91.000000        Mkt&Fin
# 211         211      M     72.00   Sci&Tech     No  74.000000        Mkt&Fin
# 212         212      M     73.00  Comm&Mgmt    Yes  59.000000        Mkt&Fin
# 213         213      F     58.00  Comm&Mgmt     No  71.934272         Mkt&HR
# 214         214      M     53.00  Comm&Mgmt     No  89.000000         Mkt&HR
#
#      mba_p       salary
# ...

# %%
data['workex'].isnull().sum()
# Out:
# 0

# %%
data['mba_p'].isnull().sum()
# Out:
# 0

# %%
from sklearn.impute import SimpleImputer as si
import numpy as np

imputer = si(strategy = 'mean',missing_values = np.nan)
imputer = imputer.fit(data[['mba_p']])
data['mba_p'] = imputer.transform(data[['mba_p']])
data
# Out:
#      Unnamed: 0 gender  degree_p   degree_t workex    etest_p specialisation  \
# 0             0      M     58.00   Sci&Tech     No  55.000000         Mkt&HR
# 1             1      M     77.48   Sci&Tech    Yes  86.500000        Mkt&Fin
# 2             2      M     64.00  Comm&Mgmt     No  75.000000        Mkt&Fin
# 3             3      M     52.00   Sci&Tech     No  66.000000         Mkt&HR
# 4             4      M     73.30  Comm&Mgmt     No  96.800000        Mkt&Fin
# ..          ...    ...       ...        ...    ...        ...            ...
# 210         210      M     77.60  Comm&Mgmt     No  91.000000        Mkt&Fin
# 211         211      M     72.00   Sci&Tech     No  74.000000        Mkt&Fin
# 212         212      M     73.00  Comm&Mgmt    Yes  59.000000        Mkt&Fin
# 213         213      F     58.00  Comm&Mgmt     No  71.934272         Mkt&HR
# 214         214      M     53.00  Comm&Mgmt     No  89.000000         Mkt&HR
#
#      mba_p       salary
# ...

# %%
data['mba_p'].isnull().sum()
# Out:
# 0

# %%
import pandas as pd

data = pd.read_csv('placement 1.csv')
data
# Out:
#      Unnamed: 0 gender  degree_p   degree_t workex  etest_p specialisation  \
# 0             0      M     58.00   Sci&Tech     No     55.0         Mkt&HR
# 1             1      M     77.48   Sci&Tech    Yes     86.5        Mkt&Fin
# 2             2      M     64.00  Comm&Mgmt     No     75.0        Mkt&Fin
# 3             3      M     52.00   Sci&Tech    NaN     66.0         Mkt&HR
# 4             4      M     73.30  Comm&Mgmt     No     96.8        Mkt&Fin
# ..          ...    ...       ...        ...    ...      ...            ...
# 210         210      M     77.60  Comm&Mgmt     No     91.0        Mkt&Fin
# 211         211      M     72.00   Sci&Tech     No     74.0        Mkt&Fin
# 212         212      M     73.00  Comm&Mgmt    Yes     59.0        Mkt&Fin
# 213         213      F     58.00  Comm&Mgmt     No      NaN         Mkt&HR
# 214         214      M     53.00  Comm&Mgmt     No     89.0         Mkt&HR
#
#      mba_p       salary
# 0    58.80  270000.0000
# ...

# %%
data.drop_duplicates()
# Out:
#      Unnamed: 0 gender  degree_p   degree_t workex  etest_p specialisation  \
# 0             0      M     58.00   Sci&Tech     No     55.0         Mkt&HR
# 1             1      M     77.48   Sci&Tech    Yes     86.5        Mkt&Fin
# 2             2      M     64.00  Comm&Mgmt     No     75.0        Mkt&Fin
# 3             3      M     52.00   Sci&Tech    NaN     66.0         Mkt&HR
# 4             4      M     73.30  Comm&Mgmt     No     96.8        Mkt&Fin
# ..          ...    ...       ...        ...    ...      ...            ...
# 210         210      M     77.60  Comm&Mgmt     No     91.0        Mkt&Fin
# 211         211      M     72.00   Sci&Tech     No     74.0        Mkt&Fin
# 212         212      M     73.00  Comm&Mgmt    Yes     59.0        Mkt&Fin
# 213         213      F     58.00  Comm&Mgmt     No      NaN         Mkt&HR
# 214         214      M     53.00  Comm&Mgmt     No     89.0         Mkt&HR
#
#      mba_p       salary
# 0    58.80  270000.0000
# ...

# %%
from sklearn.impute import SimpleImputer as si
import numpy as np

imputer = si(strategy = 'mean',missing_values=np.nan)
imputer = imputer.fit(data[['degree_p','etest_p','mba_p','salary']])
data[['degree_p','etest_p','mba_p','salary']] = imputer.transform(data[['degree_p','etest_p','mba_p','salary']])
data
# Out:
#      Unnamed: 0 gender  degree_p   degree_t workex    etest_p specialisation  \
# 0             0      M     58.00   Sci&Tech     No  55.000000         Mkt&HR
# 1             1      M     77.48   Sci&Tech    Yes  86.500000        Mkt&Fin
# 2             2      M     64.00  Comm&Mgmt     No  75.000000        Mkt&Fin
# 3             3      M     52.00   Sci&Tech    NaN  66.000000         Mkt&HR
# 4             4      M     73.30  Comm&Mgmt     No  96.800000        Mkt&Fin
# ..          ...    ...       ...        ...    ...        ...            ...
# 210         210      M     77.60  Comm&Mgmt     No  91.000000        Mkt&Fin
# 211         211      M     72.00   Sci&Tech     No  74.000000        Mkt&Fin
# 212         212      M     73.00  Comm&Mgmt    Yes  59.000000        Mkt&Fin
# 213         213      F     58.00  Comm&Mgmt     No  71.934272         Mkt&HR
# 214         214      M     53.00  Comm&Mgmt     No  89.000000         Mkt&HR
#
#      mba_p       salary
# ...

# %%
data[['degree_p','etest_p','mba_p','salary']].isnull().sum()
# Out:
# degree_p    0
# etest_p     0
# mba_p       0
# salary      0
# dtype: int64

# %%
imputer = si(strategy = 'most_frequent',missing_values = np.nan)
imputer = imputer.fit(data[['degree_t','workex','specialisation']])
data[['degree_t','workex','specialisation']] = imputer.transform(data[['degree_t','workex','specialisation']])
data
# Out:
#      Unnamed: 0 gender  degree_p   degree_t workex    etest_p specialisation  \
# 0             0      M     58.00   Sci&Tech     No  55.000000         Mkt&HR
# 1             1      M     77.48   Sci&Tech    Yes  86.500000        Mkt&Fin
# 2             2      M     64.00  Comm&Mgmt     No  75.000000        Mkt&Fin
# 3             3      M     52.00   Sci&Tech     No  66.000000         Mkt&HR
# 4             4      M     73.30  Comm&Mgmt     No  96.800000        Mkt&Fin
# ..          ...    ...       ...        ...    ...        ...            ...
# 210         210      M     77.60  Comm&Mgmt     No  91.000000        Mkt&Fin
# 211         211      M     72.00   Sci&Tech     No  74.000000        Mkt&Fin
# 212         212      M     73.00  Comm&Mgmt    Yes  59.000000        Mkt&Fin
# 213         213      F     58.00  Comm&Mgmt     No  71.934272         Mkt&HR
# 214         214      M     53.00  Comm&Mgmt     No  89.000000         Mkt&HR
#
#      mba_p       salary
# ...

# %%
data[['degree_t','workex','specialisation']].isnull().sum()
# Out:
# degree_t          0
# workex            0
# specialisation    0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Unnamed: 0        0
# gender            0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# salary            0
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 0
